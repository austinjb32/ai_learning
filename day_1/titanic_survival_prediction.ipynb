# %%
# %pip install pandas
# %pip install scikit-learn
# Out:
# Requirement already satisfied: pandas in /opt/anaconda3/envs/ai-base/lib/python3.10/site-packages (2.3.0)
# Requirement already satisfied: numpy>=1.22.4 in /opt/anaconda3/envs/ai-base/lib/python3.10/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/austinjb32/.local/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/ai-base/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/ai-base/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/austinjb32/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.0-cp310-cp310-macosx_12_0_arm64.whl.metadata (31 kB)
# Requirement already satisfied: numpy>=1.22.0 in /opt/anaconda3/envs/ai-base/lib/python3.10/site-packages (from scikit-learn) (2.2.6)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Downloading scipy-1.15.3-cp310-cp310-macosx_14_0_arm64.whl.metadata (61 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.7.0-cp310-cp310-macosx_12_0_arm64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 1.6 MB/s eta 0:00:0000:0100:01m
# Using cached joblib-1.5.1-py3-none-any.whl (307 kB)
# Downloading scipy-1.15.3-cp310-cp310-macosx_14_0_arm64.whl (22.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.4/22.4 MB 2.7 MB/s eta 0:00:0000:0100:01
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [scikit-learn] [scikit-learn]
# Successfully installed joblib-1.5.1 scikit-learn-1.7.0 scipy-1.15.3 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv("train.csv")
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                           Name     Sex  \
# 140          141         0       3  Boulos, Mrs. Joseph (Sultana)  female
# 278          279         0       3             Rice, Master. Eric    male
# 285          286         0       3            Stankovic, Mr. Ivan    male
# 659          660         0       1     Newell, Mr. Arthur Webster    male
# 544          545         0       1     Douglas, Mr. Walter Donald    male
#
#       Age  SibSp  Parch    Ticket      Fare Cabin Embarked
# 140   NaN      0      2      2678   15.2458   NaN        C
# 278   7.0      4      1    382652   29.1250   NaN        Q
# 285  33.0      0      0    349239    8.6625   NaN        C
# 659  58.0      0      2     35273  113.2750   D48        C
# 544  50.0      1      0  PC 17761  106.4250   C86        C

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['Age'].describe(), df['Cabin'].describe(), df['Embarked'].describe()
# Out:
# (count    714.000000
#  mean      29.699118
#  std       14.526497
#  min        0.420000
#  25%       20.125000
#  50%       28.000000
#  75%       38.000000
#  max       80.000000
#  Name: Age, dtype: float64,
#  count         204
#  unique        147
#  top       B96 B98
#  freq            4
#  Name: Cabin, dtype: object,
#  count     889
#  unique      3
#  top         S
#  freq      644
#  Name: Embarked, dtype: object)

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)
# Out:
# /var/folders/z_/ymsj27jj6xd8s9z26s2hwtw40000gn/T/ipykernel_33012/1698716155.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(), inplace=True)

# %%
df.drop(['Cabin'], axis=1, inplace=True)

# %%
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 671          672         0       1                   Davidson, Mr. Thornton
# 107          108         1       3                   Moss, Mr. Albert Johan
# 488          489         0       3            Somerton, Mr. Francis William
# 658          659         0       2             Eitemiller, Mr. George Floyd
# 472          473         1       2  West, Mrs. Edwy Arthur (Ada Mary Worth)
# 480          481         0       3           Goodwin, Master. Harold Victor
# 126          127         0       3                      McMahon, Mr. Martin
# 538          539         0       3                 Risien, Mr. Samuel Beard
# 582          583         0       2               Downton, Mr. William James
# 286          287         1       3                  de Mulder, Mr. Theodore
#
#         Sex        Age  SibSp  Parch      Ticket    Fare Embarked
# 671    male  31.000000      1      0  F.C. 12750  52.000        S
# 107    male  29.699118      0      0      312991   7.775        S
# 488    male  30.000000      0      0  A.5. 18509   8.050        S
# 658    male  23.000000      0      0       29751  13.000        S
# 472  female  33.000000      1      2  C.A. 34651  27.750        S
# 480    male   9.000000      5      2     CA 2144  46.900        S
# 126    male  29.699118      0      0      370372   7.750        Q
# 538    male  29.699118      0      0      364498  14.500        S
# 582    male  54.000000      0      0       28403  26.000        S
# 286    male  30.000000      0      0      345774   9.500        S

# %%
df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})

# %%
df = pd.get_dummies(df, columns=['Embarked'], drop_first=True)

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass                          Name  Sex  \
# 828          829         1       3  McCormack, Mr. Thomas Joseph    0
# 881          882         0       3            Markun, Mr. Johann    0
# 595          596         0       3   Van Impe, Mr. Jean Baptiste    0
# 195          196         1       1          Lurette, Miss. Elise    1
# 141          142         1       3      Nysten, Miss. Anna Sofia    1
# 855          856         1       3    Aks, Mrs. Sam (Leah Rosen)    1
# 324          325         0       3      Sage, Mr. George John Jr    0
# 229          230         0       3       Lefebre, Miss. Mathilde    1
# 327          328         1       2       Ball, Mrs. (Ada E Hall)    1
# 749          750         0       3       Connaghton, Mr. Michael    0
#
#            Age  SibSp  Parch    Ticket      Fare  Embarked_Q  Embarked_S
# 828  29.699118      0      0    367228    7.7500        True       False
# 881  33.000000      0      0    349257    7.8958       False        True
# 595  36.000000      1      1    345773   24.1500       False        True
# 195  58.000000      0      0  PC 17569  146.5208       False       False
# 141  22.000000      0      0    347081    7.7500       False        True
# 855  18.000000      0      1    392091    9.3500       False        True
# 324  29.699118      8      2  CA. 2343   69.5500       False        True
# 229  29.699118      3      1      4133   25.4667       False        True
# 327  36.000000      0      0     28551   13.0000       False        True
# 749  31.000000      0      0    335097    7.7500        True       False

# %%
features = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked_Q' , 'Embarked_S']
x = df[features]
y = df['Survived']
x.sample(5), y.sample(5)
# Out:
# (     Pclass  Sex        Age  SibSp  Parch    Fare  Embarked_Q  Embarked_S
#  522       3    0  29.699118      0      0   7.225       False       False
#  18        3    1  31.000000      1      0  18.000       False        True
#  437       2    1  24.000000      2      3  18.750       False        True
#  559       3    1  36.000000      1      0  17.400       False        True
#  276       3    1  45.000000      0      0   7.750       False        True,
#  527    0
#  835    1
#  279    1
#  247    1
#  42     0
#  Name: Survived, dtype: int64)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=1000)
model.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
y_pred = model.predict(x_test)
# Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8100558659217877
# Confusion Matrix:
#  [[90 15]
#  [19 55]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.86      0.84       105
#            1       0.79      0.74      0.76        74
#
#     accuracy                           0.81       179
#    macro avg       0.81      0.80      0.80       179
# weighted avg       0.81      0.81      0.81       179
